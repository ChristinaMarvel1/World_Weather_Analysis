# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID                    City Country  Max Temp Current Description  \
# 0        0            San Patricio      US     88.52       broken clouds
# 1        5                     Gao      ML     88.54     overcast clouds
# 2        8                  Atuona      PF     77.77           clear sky
# 3       14                 Phichit      TH     84.43     overcast clouds
# 4       15  Sao Miguel Do Araguaia      BR     76.21          few clouds
#
#        Lat       Lng              Hotel Name
# 0  28.0170  -97.5169      Motel 6 Sinton, TX
# 1  16.6362    1.6370                     NaN
# 2  -9.8000 -139.0333             Villa Enata
# 3  16.2500  100.4167      Rommakham Homestay
# 4 -13.2750  -50.1628  Hotel Executivo Palace

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Vacationing to the US and setting new data frame

us_vacation_df = vacation_df.loc[(vacation_df["Country"] == "US")]
us_vacation_df.dropna()
# Out:
#      City_ID               City Country  Max Temp   Current Description  \
# 0          0       San Patricio      US     88.52         broken clouds
# 10        26             Bethel      US     80.69             clear sky
# 22        62          Plainview      US     82.26             clear sky
# 37       103             Lompoc      US     79.02             clear sky
# 48       124              Kapaa      US     84.18      scattered clouds
# 52       132          Ewa Beach      US     87.75         broken clouds
# 56       143          Nantucket      US     80.71                  mist
# 59       158               Hilo      US     88.29  heavy intensity rain
# 63       165       Mastic Beach      US     79.05             clear sky
# 67       183  Steamboat Springs      US     80.19             clear sky
# 80       228          San Ramon      US     85.60             clear sky
# 84       241           Ahuimanu      US     87.51             clear sky
# 93       270            College      US     78.08            few clouds
# 96       276         Torrington      US     76.12         broken clouds
# 101      286       Poplar Bluff      US     85.73             clear sky
# 108      304            Kahului      US     87.82      scattered clouds
# 119      321       Myrtle Beach      US     82.45             clear sky
# 123      334              Rodeo      US     83.07             clear sky
# 127      338           Marshall      US     84.51             clear sky
# 147      388              Craig      US     82.35             clear sky
# 152      399               Mayo      US     78.37       overcast clouds
# 187      481          Lake City      US     81.79       overcast clouds
# 194      496           Freeport      US     84.33             clear sky
# 196      503           Morehead      US     78.78      scattered clouds
# 204      530         Zanesville      US     75.76             clear sky
# 210      544        Fort Morgan      US     83.62             clear sky
# 215      550       South Valley      US     87.21         broken clouds
# 222      561             Dennis      US     78.75       overcast clouds
# 235      589          Fairbanks      US     78.10            few clouds
# 239      611           Sheridan      US     84.02             clear sky
# 241      614            Russell      US     82.00      scattered clouds
# 246      631       Saint Simons      US     85.01             clear sky
# 252      648           Hamilton      US     77.40            few clouds
# 262      681            Natchez      US     80.82             clear sky
#
#          Lat       Lng                                         Hotel Name
# 0    28.0170  -97.5169                                 Motel 6 Sinton, TX
# 10   41.3712  -73.4140                      Courtyard by Marriott Danbury
# 22   40.7765  -73.4673       Four Points by Sheraton Melville Long Island
# 37   34.6391 -120.4579           Holiday Inn Express Lompoc, an IHG Hotel
# 48   22.0752 -159.3190                Sheraton Kauai Coconut Beach Resort
# 52   21.3156 -158.0072                                       Base Lodging
# 56   41.2835  -70.0995                                 Jared Coffin House
# 59   19.7297 -155.0900                                Hilo Hawaiian Hotel
# 63   40.7668  -72.8521               Brushwood House by Smith Point Beach
# 67   40.4850 -106.8317                                    Steamboat Grand
# 80   37.7799 -121.9780                                 San Ramon Marriott
# 84   21.4447 -157.8378                                Paradise Bay Resort
# 93   64.8569 -147.8028                            Pike's Waterfront Lodge
# 96   41.8007  -73.1212                              The Yankee Pedlar Inn
# 101  36.7570  -90.3929                           Holiday Inn Poplar Bluff
# 108  20.8947 -156.4700                                 Maui Seaside Hotel
# 119  33.6891  -78.8867                       Bay View Resort Myrtle Beach
# 123  38.0330 -122.2669                                  Captain's Cottage
# 127  34.3834  -86.3333                               Riverview Campground
# 147  40.5153 -107.5464    Candlewood Suites Craig-Northwest, an IHG Hotel
# 152  38.8876  -76.5119               Resorts Resource Group International
# 187  30.1897  -82.6393                           Ramada Limited Lake City
# 194  40.6576  -73.5832                        The Freeport Inn and Marina
# 196  37.2711  -87.1764                                    CCI Express Inn
# 204  39.9404  -82.0132  Holiday Inn Express & Suites Zanesville North,...
# 210  40.2503 -103.8000                            Hampton Inn Fort Morgan
# 215  35.0101 -106.6781                               desert palms rv park
# 222  41.7354  -70.1939                                Sesuit Harbor House
# 235  64.8378 -147.7164       Westmark Fairbanks Hotel & Conference Center
# 239  44.8333 -106.9173                               Comfort Inn & Suites
# 241  32.3502  -85.1999                                               Macs
# 246  31.1352  -81.3901  Holiday Inn Express Saint Simons Island, an IH...
# 252  39.1834  -84.5333                          Six Acres Bed & Breakfast
# 262  31.5604  -91.4032                       Hampton Inn & Suites Natchez

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 

start = float(input("What is your Starting City_ID from US List you would like for your trip? "))
stop1 = float(input("What is your First Stop City_ID from US List you would like for your trip? "))
stop2 = float(input("What is your Second Stop City_ID from US List you would like for your trip? "))
stop3 = float(input("What is your Third Stop City_ID from US List you would like for your trip? "))
end = float(input("What is your Last City_ID from US List you would like for your trip? "))
# Out:
# What is your Starting City_ID from US List you would like for your trip? 321
# What is your First Stop City_ID from US List you would like for your trip? 631
# What is your Second Stop City_ID from US List you would like for your trip? 481
# What is your Third Stop City_ID from US List you would like for your trip? 0
# What is your Last City_ID from US List you would like for your trip? 321

# %%
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

# Start Vacation at:

vacation_start = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop1)]
vacation_start = vacation_start.iloc[0]

vacation_stop1 = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop2)]
vacation_stop1 = vacation_stop1.iloc[0]

vacation_stop2 = us_vacation_df.loc[(us_vacation_df["City_ID"] == stop3)]
vacation_stop2 = vacation_stop2.iloc[0]

vacation_stop3 = us_vacation_df.loc[(us_vacation_df["City_ID"] == end)]
vacation_stop3 = vacation_stop3.iloc[0]

vacation_end = us_vacation_df.loc[(us_vacation_df["City_ID"] == end)]
vacation_end = vacation_end.iloc[0] 
                                     
print("Your Starting Destination is " + vacation_start["City"] + ", " + vacation_start["Country"])
print("Your Frist Stop is " + vacation_stop1["City"] + ", " + vacation_stop1["Country"])
print("Your Second Stop is " + vacation_stop2["City"] + ", " + vacation_stop2["Country"])                                     
print("Your Third Stop is " + vacation_stop3["City"] + ", " + vacation_stop3["Country"])                                     
print("Your Last Stop in your vacation is " + vacation_end["City"] + ", " + vacation_end["Country"])
# Out:
# Your Starting Destination is Saint Simons, US
# Your Frist Stop is Lake City, US
# Your Second Stop is San Patricio, US
# Your Third Stop is Myrtle Beach, US
# Your Last Stop in your vacation is Myrtle Beach, US

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]]
print(start)
# Out:
# Lat    31.1352
# Lng   -81.3901
# Name: 246, dtype: object

# %%
stop1 = vacation_stop1[["Lat", "Lng"]]
print(stop1)
# Out:
# Lat    30.1897
# Lng   -82.6393
# Name: 187, dtype: object

# %%
stop2 = vacation_stop2[["Lat", "Lng"]]
print(stop2)
# Out:
# Lat     28.017
# Lng   -97.5169
# Name: 0, dtype: object

# %%
stop3 = vacation_stop3[["Lat", "Lng"]]
print(stop3)
# Out:
# Lat    33.6891
# Lng   -78.8867
# Name: 119, dtype: object

# %%
end = vacation_end[["Lat", "Lng"]]
print(end)
# Out:
# Lat    33.6891
# Lng   -78.8867
# Name: 119, dtype: object

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# (USING DRIVING MODE)

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

start = (31.1352, -81.3901)
stop1 = (30.1897, -82.6393)
stop2 = (28.017, -97.5169)
stop3 = (33.6891, -78.8867)
end = (33.6891, -78.8867)

fig = gmaps.figure()
start2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(start2end_via_stops)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
us_vacation_df = pd.concat([us_vacation_df],ignore_index=True)
us_vacation_df
# Out:
#     City_ID               City Country  Max Temp   Current Description  \
# 0         0       San Patricio      US     88.52         broken clouds
# 1        26             Bethel      US     80.69             clear sky
# 2        62          Plainview      US     82.26             clear sky
# 3        65              Avera      US     83.71       overcast clouds
# 4       103             Lompoc      US     79.02             clear sky
# 5       124              Kapaa      US     84.18      scattered clouds
# 6       132          Ewa Beach      US     87.75         broken clouds
# 7       143          Nantucket      US     80.71                  mist
# 8       158               Hilo      US     88.29  heavy intensity rain
# 9       165       Mastic Beach      US     79.05             clear sky
# 10      183  Steamboat Springs      US     80.19             clear sky
# 11      228          San Ramon      US     85.60             clear sky
# 12      241           Ahuimanu      US     87.51             clear sky
# 13      270            College      US     78.08            few clouds
# 14      276         Torrington      US     76.12         broken clouds
# 15      286       Poplar Bluff      US     85.73             clear sky
# 16      304            Kahului      US     87.82      scattered clouds
# 17      321       Myrtle Beach      US     82.45             clear sky
# 18      334              Rodeo      US     83.07             clear sky
# 19      338           Marshall      US     84.51             clear sky
# 20      388              Craig      US     82.35             clear sky
# 21      399               Mayo      US     78.37       overcast clouds
# 22      481          Lake City      US     81.79       overcast clouds
# 23      496           Freeport      US     84.33             clear sky
# 24      503           Morehead      US     78.78      scattered clouds
# 25      530         Zanesville      US     75.76             clear sky
# 26      544        Fort Morgan      US     83.62             clear sky
# 27      550       South Valley      US     87.21         broken clouds
# 28      561             Dennis      US     78.75       overcast clouds
# 29      589          Fairbanks      US     78.10            few clouds
# 30      611           Sheridan      US     84.02             clear sky
# 31      614            Russell      US     82.00      scattered clouds
# 32      631       Saint Simons      US     85.01             clear sky
# 33      648           Hamilton      US     77.40            few clouds
# 34      681            Natchez      US     80.82             clear sky
#
#         Lat       Lng                                         Hotel Name
# 0   28.0170  -97.5169                                 Motel 6 Sinton, TX
# 1   41.3712  -73.4140                      Courtyard by Marriott Danbury
# 2   40.7765  -73.4673       Four Points by Sheraton Melville Long Island
# 3   33.1940  -82.5271                                                NaN
# 4   34.6391 -120.4579           Holiday Inn Express Lompoc, an IHG Hotel
# 5   22.0752 -159.3190                Sheraton Kauai Coconut Beach Resort
# 6   21.3156 -158.0072                                       Base Lodging
# 7   41.2835  -70.0995                                 Jared Coffin House
# 8   19.7297 -155.0900                                Hilo Hawaiian Hotel
# 9   40.7668  -72.8521               Brushwood House by Smith Point Beach
# 10  40.4850 -106.8317                                    Steamboat Grand
# 11  37.7799 -121.9780                                 San Ramon Marriott
# 12  21.4447 -157.8378                                Paradise Bay Resort
# 13  64.8569 -147.8028                            Pike's Waterfront Lodge
# 14  41.8007  -73.1212                              The Yankee Pedlar Inn
# 15  36.7570  -90.3929                           Holiday Inn Poplar Bluff
# 16  20.8947 -156.4700                                 Maui Seaside Hotel
# 17  33.6891  -78.8867                       Bay View Resort Myrtle Beach
# 18  38.0330 -122.2669                                  Captain's Cottage
# 19  34.3834  -86.3333                               Riverview Campground
# 20  40.5153 -107.5464    Candlewood Suites Craig-Northwest, an IHG Hotel
# 21  38.8876  -76.5119               Resorts Resource Group International
# 22  30.1897  -82.6393                           Ramada Limited Lake City
# 23  40.6576  -73.5832                        The Freeport Inn and Marina
# 24  37.2711  -87.1764                                    CCI Express Inn
# 25  39.9404  -82.0132  Holiday Inn Express & Suites Zanesville North,...
# 26  40.2503 -103.8000                            Hampton Inn Fort Morgan
# 27  35.0101 -106.6781                               desert palms rv park
# 28  41.7354  -70.1939                                Sesuit Harbor House
# 29  64.8378 -147.7164       Westmark Fairbanks Hotel & Conference Center
# 30  44.8333 -106.9173                               Comfort Inn & Suites
# 31  32.3502  -85.1999                                               Macs
# 32  31.1352  -81.3901  Holiday Inn Express Saint Simons Island, an IH...
# 33  39.1834  -84.5333                          Six Acres Bed & Breakfast
# 34  31.5604  -91.4032                       Hampton Inn & Suites Natchez

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in us_vacation_df.iterrows()]
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = us_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

city_mark = us_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# %%
# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
