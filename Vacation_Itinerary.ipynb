# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID                    City Country  Max Temp Current Description  \
# 0        0            San Patricio      US     88.52       broken clouds
# 1        5                     Gao      ML     88.54     overcast clouds
# 2        8                  Atuona      PF     77.77           clear sky
# 3       14                 Phichit      TH     84.43     overcast clouds
# 4       15  Sao Miguel Do Araguaia      BR     76.21          few clouds
#
#        Lat       Lng              Hotel Name
# 0  28.0170  -97.5169      Motel 6 Sinton, TX
# 1  16.6362    1.6370                     NaN
# 2  -9.8000 -139.0333             Villa Enata
# 3  16.2500  100.4167      Rommakham Homestay
# 4 -13.2750  -50.1628  Hotel Executivo Palace

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Vacationing to Brazil and setting new data frame

brazil_vacation_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
brazil_vacation_df.dropna()
# Out:
#      City_ID                    City Country  Max Temp Current Description  \
# 4         15  Sao Miguel Do Araguaia      BR     76.21          few clouds
# 33        97                Canutama      BR     78.26           clear sky
# 61       161      Sao Felix Do Xingu      BR     79.59     overcast clouds
# 68       187                  Labrea      BR     76.86           clear sky
# 78       219               Boa Vista      BR     76.98    scattered clouds
# 90       264                  Maraba      BR     75.38           clear sky
# 95       272                Araioses      BR     78.94     overcast clouds
# 105      298                 Itarema      BR     77.38       broken clouds
# 134      363                 Prainha      BR     76.06     overcast clouds
# 142      378              Carutapera      BR     76.96     overcast clouds
# 173      453                  Acarau      BR     77.22    scattered clouds
# 189      487             Salinopolis      BR     79.41     overcast clouds
# 209      543                Santarem      BR     77.13          few clouds
# 231      574                Alenquer      BR     75.78           clear sky
# 256      657                   Natal      BR     75.42           clear sky
#
#          Lat      Lng                          Hotel Name
# 4   -13.2750 -50.1628              Hotel Executivo Palace
# 33   -6.5339 -64.3831                     Hotel Jhennifer
# 61   -6.6447 -51.9950                   Rio Xingu Camping
# 68   -7.2586 -64.7981                Hotel Novo Horizonte
# 78    2.8197 -60.6733                  Aipana Plaza Hotel
# 90   -5.3686 -49.1178                  Hotel Del Principe
# 95   -2.8900 -41.9031                Pousada Vale do Magú
# 105  -2.9248 -39.9167  Sea Lounge! Bar, Club & Restaurant
# 134  -1.8000 -53.4800                          Casa Rocha
# 142  -1.1950 -46.0200                              Lidera
# 173  -2.8856 -40.1200                    castelo pizzaria
# 189  -0.6136 -47.3561  Salinas Park Resort Maçarico AP101
# 209  -2.4431 -54.7083                     Hotel Imperador
# 231  -1.9417 -54.7383                       Detinha Hotel
# 256  -5.7950 -35.2094            Villa Park Hotel | Natal

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 

start = float(input("What is your Starting City_ID from BR List you would like for your trip? "))
stop1 = float(input("What is your First Stop City_ID from BR List you would like for your trip? "))
stop2 = float(input("What is your Second Stop City_ID from BR List you would like for your trip? "))
stop3 = float(input("What is your Thirth Stop City_ID from BR List you would like for your trip? "))
end = float(input("What is your Last City_ID from BR List you would like for your trip? "))
# Out:
# What is your Starting City_ID from BR List you would like for your trip? 298
# What is your First Stop City_ID from BR List you would like for your trip? 453
# What is your Second Stop City_ID from BR List you would like for your trip? 487
# What is your Thirth Stop City_ID from BR List you would like for your trip? 657
# What is your Last City_ID from BR List you would like for your trip? 298

# %%
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

# Start Vacation at:

vacation_start = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop1)]
vacation_start = vacation_start.iloc[0]

vacation_stop1 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop2)]
vacation_stop1 = vacation_stop1.iloc[0]

vacation_stop2 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop3)]
vacation_stop2 = vacation_stop2.iloc[0]

vacation_stop3 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == end)]
vacation_stop3 = vacation_stop3.iloc[0]

vacation_end = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] <= end)]
vacation_end = vacation_end.iloc[0] 
                                     
print("Your Starting Destination is " + vacation_start["City"] + ", " + vacation_start["Country"])
print("Your Frist Stop is " + vacation_stop1["City"] + ", " + vacation_stop1["Country"])
print("Your Second Stop is " + vacation_stop2["City"] + ", " + vacation_stop2["Country"])                                     
print("Your Thirth Stop is " + vacation_stop3["City"] + ", " + vacation_stop3["Country"])                                     
print("Your Last Stop in your vacation is " + vacation_end["City"] + ", " + vacation_end["Country"])
# Out:
# Your Starting Destination is Acarau, BR
# Your Frist Stop is Salinopolis, BR
# Your Second Stop is Natal, BR
# Your Thirth Stop is Itarema, BR
# Your Last Stop in your vacation is Sao Miguel Do Araguaia, BR

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]]
print(start)
# Out:
# Lat   -2.8856
# Lng    -40.12
# Name: 173, dtype: object

# %%
stop1 = vacation_stop1[["Lat", "Lng"]]
print(stop1)
# Out:
# Lat    -0.6136
# Lng   -47.3561
# Name: 189, dtype: object

# %%
stop2 = vacation_stop2[["Lat", "Lng"]]
print(stop2)
# Out:
# Lat     -5.795
# Lng   -35.2094
# Name: 256, dtype: object

# %%
stop3 = vacation_stop3[["Lat", "Lng"]]
print(stop3)
# Out:
# Lat    -2.9248
# Lng   -39.9167
# Name: 105, dtype: object

# %%
end = vacation_end[["Lat", "Lng"]]
print(end)
# Out:
# Lat    -13.275
# Lng   -50.1628
# Name: 4, dtype: object

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# (USING DRIVING MODE)

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

start = (20.7, -105.2)
stop1 = (17.48, -91.43)
stop2 = (27.98, -114.06)
stop3 = (23.17, -97.95)
end = (30.85, -116.07)

fig = gmaps.figure()
sart2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(sart2end_via_stops)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
brazil_vacation_df = pd.concat([brazil_vacation_df],ignore_index=True)
brazil_vacation_df
# Out:
#     City_ID                    City Country  Max Temp Current Description  \
# 0        15  Sao Miguel Do Araguaia      BR     76.21          few clouds
# 1        97                Canutama      BR     78.26           clear sky
# 2       161      Sao Felix Do Xingu      BR     79.59     overcast clouds
# 3       187                  Labrea      BR     76.86           clear sky
# 4       219               Boa Vista      BR     76.98    scattered clouds
# 5       264                  Maraba      BR     75.38           clear sky
# 6       272                Araioses      BR     78.94     overcast clouds
# 7       298                 Itarema      BR     77.38       broken clouds
# 8       363                 Prainha      BR     76.06     overcast clouds
# 9       378              Carutapera      BR     76.96     overcast clouds
# 10      453                  Acarau      BR     77.22    scattered clouds
# 11      487             Salinopolis      BR     79.41     overcast clouds
# 12      543                Santarem      BR     77.13          few clouds
# 13      574                Alenquer      BR     75.78           clear sky
# 14      657                   Natal      BR     75.42           clear sky
#
#         Lat      Lng                          Hotel Name
# 0  -13.2750 -50.1628              Hotel Executivo Palace
# 1   -6.5339 -64.3831                     Hotel Jhennifer
# 2   -6.6447 -51.9950                   Rio Xingu Camping
# 3   -7.2586 -64.7981                Hotel Novo Horizonte
# 4    2.8197 -60.6733                  Aipana Plaza Hotel
# 5   -5.3686 -49.1178                  Hotel Del Principe
# 6   -2.8900 -41.9031                Pousada Vale do Magú
# 7   -2.9248 -39.9167  Sea Lounge! Bar, Club & Restaurant
# 8   -1.8000 -53.4800                          Casa Rocha
# 9   -1.1950 -46.0200                              Lidera
# 10  -2.8856 -40.1200                    castelo pizzaria
# 11  -0.6136 -47.3561  Salinas Park Resort Maçarico AP101
# 12  -2.4431 -54.7083                     Hotel Imperador
# 13  -1.9417 -54.7383                       Detinha Hotel
# 14  -5.7950 -35.2094            Villa Park Hotel | Natal

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in brazil_vacation_df.iterrows()]
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = brazil_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

city_mark = brazil_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# %%
# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
